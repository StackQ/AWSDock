# %%
from IPython.display import Image
Image('/workspaces/MobyDock/AWS/AWS Certified Cloud Practitioner CLF-C02/images/IAM/IAM_users_groups.png')

# %%
from IPython.display import Image
Image('images/IAM/IAM_permissions.png')

# %%
from IPython.display import Image
Image('images/IAM/IAM_policies_inheritance.png')

# %%
from IPython.display import Image
Image('images/IAM/IAM_policies_structure.png')

# %%
IAM > Policies > AdministratorAccess

Allow (403 of 403 services)

{
    "Version": "2012-10-17",
    "Statement": [
        {
            "Effect": "Allow",
            "Action": "*",
            "Resource": "*"
        }
    ]
}

IAM > Policies > AdministratorAccess
Allow (1 of 403 services)

{
    "Version": "2012-10-17",
    "Statement": [
        {
            "Effect": "Allow",
            "Action": [
                "iam:GenerateCredentialReport",
                "iam:GenerateServiceLastAccessedDetails",
                "iam:Get*",
                "iam:List*",
                "iam:SimulateCustomPolicy",
                "iam:SimulatePrincipalPolicy"
            ],
            "Resource": "*"
        }
    ]
}

IAM > Policies > Create > Visual/JSON >

{
    "Version": "2012-10-17",
    "Statement": [
        {
            "Sid": "VisualEditor0",
            "Effect": "Allow",
            "Action": [
                "iam:ListUserPolicies",
                "iam:GetUser"
            ],
            "Resource": "*"
        }
    ]
}

# %%
from IPython.display import Image
Image('images/IAM/IAM_mfa_overview.png')

# %%
from IPython.display import Image
Image('images/IAM/aws_access_ways.png')

# %%
from IPython.display import Image
Image('images/IAM/what_aws_cli.png')

# %%
from IPython.display import Image
Image('images/IAM/what_aws_sdk.png')

# %%
from IPython.display import Image
Image('images/IAM/IAM_roles_for_services.png')

# %%
from IPython.display import Image
Image('images/IAM/DemoRoleForEC2.png')
#Permissions -> Permissions policies = IAMReadOnlyAccess

# %%
from IPython.display import Image
Image('images/IAM/IAM_security_tools.png')

# %%
from IPython.display import Image
Image('images/IAM/IAM_access_advisor.png')

# %%
from IPython.display import Image
Image('images/IAM/IAM_shared_responsibility_model.png')

# %%
from IPython.display import Image
Image('images/IAM/IAM_summary.png')
